# %% [markdown]
# # Orchestration Logic

# %%
notebooks = [
    "./gold.dim_customers",
    "./gold.dim_products",
    "./gold.fact_sales"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
